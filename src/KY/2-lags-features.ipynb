# %% [markdown]
# **Pandas Aggregate’s cousin - Transform:**
#
# https://towardsdatascience.com/pandas-transform-more-than-meets-the-eye-928542b40b56
#
# **Lag Features & Rolling Window Statistics:**
#
# https://machinelearningmastery.com/basic-feature-engineering-time-series-data-python/

# %% [markdown]
# A description of features since I found the idea of using lags and rolling windows fascinating. I just wanted to have some kind of an "intuition" of it. So here are the notes:
#
# **First off what each feature mathematically does**
#
# *   lag_7: sales shifted 7 steps downwards for each group. That is why the first value appears on the 7th index.
#
# *   lag_28: sales shifted 28 steps downwards. That is why the first value appears on the 28th index.
#
# *   rmean_7_7: rolling mean sales of a window size of 7 over column *lag_7*. First value (0.2857) appears on the 13th index because means including nan are nan.
#
# *   rmean_7_28: rolling mean sales of a window size of 28 over column *lag_7*. First value (0.357) appears on the 34th index because that is the first time the mean formula gets all 28 non-nan values.
#
# *   rmean_28_7: rolling mean sales of a window size of 7 over column *lag_28*. First value (0.2857) appears on the 3th index because it is the first time the mean formula gets 7 non-nan values.
#
# *   rmean_28_28: rolling mean sales of a window size of 28 over column *lag_28*. First value appears on 55th index because that is the first time the formula here all non-nan values.
#
# **The intuition as far as I can understand is the following:**
#
# 1. Captures the week-on-week similarity and that too of just the past week. In other words, people are likely to shop this monday similar to the last monday (except it is some special occassion).
#
# 2. Captures the weekly similarity from a month-to-month perspective. Example: people in the 1st weekend of a month shop more so that weekend looks more similar to first weeks of other months than the previous weekend. (Though 28 is arguable here. A month is generally 30. Interesting would be a variable window depending on when the comparative week starts. Dealing with edge cases like week divided into 2 months will be tricky).
#
# **Since individual data points are prone to erratic spikes or troughs, mean provides a more "representative" picture.**
#
# 3. Captures the information regarding the sales of the whole previous week ending 7 days in the past i.e. if we are at day 14, then the average is of sales from days 1-7 NOT days 7-14. This provides the information about the whole week and not just a single day sale comparison like lag_7 to bring the lag_7 value into "better weekly context".
#
# 4. Captures the information regarding the sales of the entire previous 4 weeks ending 7 days in the past i.e. if we are at day 35, then the average is sales from days 1-28.
#
# 5. Captures the information regarding the sales of the whole week ending 4 weeks ago i.e. if we are on day 35, then the average is of sales from day 1-7. (Assuming for simplicity the month is 28 days), this provides the information of not just a month-to-month comparison of the same day (day 7 of month one vs day 7 of month two), but the entire week leading up to day 7. Again the idea I believe is to capture the whole week and not just a single day sale comparison like lag_28 to bring the lag_28 value into "better weekly context".
#
# 6. Captures the information regarding the sales of the entire previous 4 weeks ending 4 weeks in the past i.e. if we are at day 56, then the average is of days 1-28. (Assuming for simplicity the month is 28 days), the idea again is to bring the point value of lag_28 into a better context (i.e. of day 28 when being compared to day 56) into a "better monthly context".
#
# How would you "talk" about these features?
#
# Hey let's see how the sales were last friday compared to this friday?
# Hey let's see how the sales were first weekend of the last month compared to first weekend of this month?
# May be comparing last saturday to this saturday is too specific. Week-on-week same day trends are more likely to be similar if the prior week went similar too. It would make sense to not just have the last saturday but also the mean of the whole week leading upto that day to give the model the "hint" how normal the whole week was.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# %cd /content/gdrive/My Drive/M5-Evaluation
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# /content/gdrive/.shortcut-targets-by-id/1IRMYDLHp5HGU8lqmV_ly3a9orQWGxVGB/M5-Evaluation

# %%
# General imports
import numpy as np
import pandas as pd
import os, sys, gc, time, warnings, pickle, psutil, random

import time

warnings.filterwarnings('ignore')

# %%
## Simple "Memory profilers" to see memory usage
def get_memory_usage():
    return np.round(psutil.Process(os.getpid()).memory_info()[0]/2.**30, 2) 
        
def sizeof_fmt(num, suffix='B'):
    for unit in ['','Ki','Mi','Gi','Ti','Pi','Ei','Zi']:
        if abs(num) < 1024.0:
            return "%3.1f%s%s" % (num, unit, suffix)
        num /= 1024.0
    return "%.1f%s%s" % (num, 'Yi', suffix)

# %%
########################### Vars
#################################################################################
TARGET = 'sales'         # Our main target
END_TRAIN = 1941         # Last day in train set
MAIN_INDEX = ['id','d']  # We can identify item by these columns

DATA_PATH = './input/m5-forecasting-accuracy/'
OUTPUT_PATH = './output/KY/'

# %%
########################### Load Data
#################################################################################
print('Load Main Data')

# We will need only train dataset
# to show lags concept
train_df = pd.read_csv(f"{DATA_PATH}/sales_train_evaluation.csv")

# To make all calculations faster
# we will limit dataset by 'CA' state
train_df = train_df[train_df['state_id']=='CA']
# Out:
# Load Main Data

# %%
########################### Data Representation
#################################################################################

# Let's check our shape
print('Shape', train_df.shape)
# Out:
# Shape (12196, 1947)

# %%
## Horizontal representation

# If we feed directly this data to model
# our label will be values in column 'd_1913'
# all other columns will be our "features"

# In lag terminology all d_1->d_1912 columns
# are our lag features 
# (target values in previous time period)

# Good thing that we have a lot of features here
# Bad thing is that we have just 12196 "train rows"
# Note: here and after all numbers are limited to 'CA' state
train_df.iloc[:10]
# Out:
#                               id        item_id  ... d_1940 d_1941
# 0  HOBBIES_1_001_CA_1_evaluation  HOBBIES_1_001  ...      0      1
# 1  HOBBIES_1_002_CA_1_evaluation  HOBBIES_1_002  ...      0      0
# 2  HOBBIES_1_003_CA_1_evaluation  HOBBIES_1_003  ...      0      1
# 3  HOBBIES_1_004_CA_1_evaluation  HOBBIES_1_004  ...      2      6
# 4  HOBBIES_1_005_CA_1_evaluation  HOBBIES_1_005  ...      1      0
# 5  HOBBIES_1_006_CA_1_evaluation  HOBBIES_1_006  ...      2      0
# 6  HOBBIES_1_007_CA_1_evaluation  HOBBIES_1_007  ...      1      0
# 7  HOBBIES_1_008_CA_1_evaluation  HOBBIES_1_008  ...     40     32
# 8  HOBBIES_1_009_CA_1_evaluation  HOBBIES_1_009  ...      1      0
# 9  HOBBIES_1_010_CA_1_evaluation  HOBBIES_1_010  ...      0      1
#
# [10 rows x 1947 columns]

# %%
## Vertical representation

# In other hand we can think of d_ columns
# as additional labels and can significantly 
# scale up our training set to 23330948 rows

# Good thing that our model will have 
# greater input for training
# Bad thing that we are losing lags that we had
# in horizontal representation and
# also new data set consumes much more memory

index_columns = ['id','item_id','dept_id','cat_id','store_id','state_id']
train_df = pd.melt(train_df, 
                  id_vars = index_columns, 
                  var_name = 'd', 
                  value_name = TARGET)

train_df[train_df['id']=='HOBBIES_1_001_CA_1_evaluation'].iloc[:10]
# Out:
#                                    id        item_id  ...     d sales
# 0       HOBBIES_1_001_CA_1_evaluation  HOBBIES_1_001  ...   d_1     0
# 12196   HOBBIES_1_001_CA_1_evaluation  HOBBIES_1_001  ...   d_2     0
# 24392   HOBBIES_1_001_CA_1_evaluation  HOBBIES_1_001  ...   d_3     0
# 36588   HOBBIES_1_001_CA_1_evaluation  HOBBIES_1_001  ...   d_4     0
# 48784   HOBBIES_1_001_CA_1_evaluation  HOBBIES_1_001  ...   d_5     0
# 60980   HOBBIES_1_001_CA_1_evaluation  HOBBIES_1_001  ...   d_6     0
# 73176   HOBBIES_1_001_CA_1_evaluation  HOBBIES_1_001  ...   d_7     0
# 85372   HOBBIES_1_001_CA_1_evaluation  HOBBIES_1_001  ...   d_8     0
# 97568   HOBBIES_1_001_CA_1_evaluation  HOBBIES_1_001  ...   d_9     0
# 109764  HOBBIES_1_001_CA_1_evaluation  HOBBIES_1_001  ...  d_10     0
#
# [10 rows x 8 columns]

# %%
## Some minification
train_df['d'] = train_df['d'].apply(lambda x: x[2:]).astype(np.int16)

icols = ['id','item_id','dept_id','cat_id','store_id','state_id']
for col in icols:
    train_df[col] = train_df[col].astype('category')

# %%
########################### Lags creation
#################################################################################

# We have several "code" solutions here
# As our dataset is already sorted by d values
# we can simply shift() values
# also we have to keep in mind that 
# we need to aggregate values on 'id' level

# group and shift in loop
temp_df = train_df[['id','d',TARGET]]

start_time = time.time()
for i in range(1,8):
    print('Shifting:', i)
    temp_df['lag_'+str(i)] = temp_df.groupby(['id'])[TARGET].shift(i)
    
print('%0.2f min: Time for loops' % ((time.time() - start_time) / 60))
# Out:
# Shifting: 1
# Shifting: 2
# Shifting: 3
# Shifting: 4
# Shifting: 5
# Shifting: 6
# Shifting: 7
# 0.11 min: Time for loops

# %% [markdown]
# ```
# # Or same in "compact" manner
# LAG_DAYS = [col for col in range(1,8)]
# temp_df = train_df[['id','d',TARGET]]
#
# start_time = time.time()
# temp_df = temp_df.assign(**{
#         '{}_lag_{}'.format(col, l): temp_df.groupby(['id'])[col].transform(lambda x: x.shift(l))
#         for l in LAG_DAYS
#         for col in [TARGET]
#     })
#
# print('%0.2f min: Time for bulk shift' % ((time.time() - start_time) / 60))
# ```

# %%
# The result
temp_df[temp_df['id']=='HOBBIES_1_001_CA_1_evaluation'].iloc[:10]

# You can notice many NaNs values - it's normal
# because there is no data for day 0,-1,-2
# (out of dataset time periods)

# Same works for test set
# be careful to make lag features:
# for day 1920 there is no data about day 1919 (until 1913)
# So if you want to predict day 1915 your 
# lag features have to start from 2 
# (1915(predicting day) - 1913(last day with label in dataset))
# and so on.

# There are few options to work 
# with NaNs in train set
## 1. drop it train_df[train_df['d']>MAX_LAG_DAY] 
## 1.1 in our case we already dropped some lines by release date
##     so you have find d.min() for each id
##     and drop train_df[train_df['d']>(train_df['d_min']+MAX_LAG_DAY)] 
## 2. If you want to keep it you can 
##    fill with '-1' to be able to convert to int
## 3. Leave as it is
## 4. Fill with mean -> not recommended
# Out:
#                                    id   d  sales  ...  lag_5  lag_6  lag_7
# 0       HOBBIES_1_001_CA_1_evaluation   1      0  ...    NaN    NaN    NaN
# 12196   HOBBIES_1_001_CA_1_evaluation   2      0  ...    NaN    NaN    NaN
# 24392   HOBBIES_1_001_CA_1_evaluation   3      0  ...    NaN    NaN    NaN
# 36588   HOBBIES_1_001_CA_1_evaluation   4      0  ...    NaN    NaN    NaN
# 48784   HOBBIES_1_001_CA_1_evaluation   5      0  ...    NaN    NaN    NaN
# 60980   HOBBIES_1_001_CA_1_evaluation   6      0  ...    0.0    NaN    NaN
# 73176   HOBBIES_1_001_CA_1_evaluation   7      0  ...    0.0    0.0    NaN
# 85372   HOBBIES_1_001_CA_1_evaluation   8      0  ...    0.0    0.0    0.0
# 97568   HOBBIES_1_001_CA_1_evaluation   9      0  ...    0.0    0.0    0.0
# 109764  HOBBIES_1_001_CA_1_evaluation  10      0  ...    0.0    0.0    0.0
#
# [10 rows x 10 columns]

# %%
########################### Rolling lags
#################################################################################

# We restored some day sales values from horizontal representation
# as lag features but just few of them (last 7 days or less)
# because of memory limits we can't have many lag features
# How we can get additional information from other days?

## Rolling aggregations

temp_df = train_df[['id','d','sales']]

start_time = time.time()

for i in [14,30,60]:
  print('Rolling period:', i)
  temp_df['rolling_mean_'+str(i)] = temp_df.groupby(['id'])[TARGET].apply(lambda x: x.shift(1).rolling(i).mean())
  temp_df['rolling_std_'+str(i)]  = temp_df.groupby(['id'])[TARGET].apply(lambda x: x.shift(1).rolling(i).std())

# lambda x: x.shift(1)
# 1 day shift will serve only to predict day 1914
# for other days you have to shift PREDICT_DAY-1913

# Such aggregations will help us to restore
# at least part of the information for our model
# and out of 14+30+60->104 columns we can have just 6
# with valuable information (hope it is sufficient)
# you can also aggregate by max/skew/median etc 
# also you can try other rolling periods 180,365 etc
print('%0.2f min: Time for loop' % ((time.time() - start_time) / 60))
# Out:
# Rolling period: 14
# Rolling period: 30
# Rolling period: 60
# 1.67 min: Time for loop

# %%
# The result
temp_df[temp_df['id']=='HOBBIES_1_002_CA_1_evaluation'].iloc[:20]

# Same for NaNs values - it's normal
# because there is no data for 
# 0*(rolling_period),-1*(rolling_period),-2*(rolling_period)
# Out:
#                                    id   d  ...  rolling_mean_60  rolling_std_60
# 1       HOBBIES_1_002_CA_1_evaluation   1  ...              NaN             NaN
# 12197   HOBBIES_1_002_CA_1_evaluation   2  ...              NaN             NaN
# 24393   HOBBIES_1_002_CA_1_evaluation   3  ...              NaN             NaN
# 36589   HOBBIES_1_002_CA_1_evaluation   4  ...              NaN             NaN
# 48785   HOBBIES_1_002_CA_1_evaluation   5  ...              NaN             NaN
# 60981   HOBBIES_1_002_CA_1_evaluation   6  ...              NaN             NaN
# 73177   HOBBIES_1_002_CA_1_evaluation   7  ...              NaN             NaN
# 85373   HOBBIES_1_002_CA_1_evaluation   8  ...              NaN             NaN
# 97569   HOBBIES_1_002_CA_1_evaluation   9  ...              NaN             NaN
# 109765  HOBBIES_1_002_CA_1_evaluation  10  ...              NaN             NaN
# 121961  HOBBIES_1_002_CA_1_evaluation  11  ...              NaN             NaN
# 134157  HOBBIES_1_002_CA_1_evaluation  12  ...              NaN             NaN
# 146353  HOBBIES_1_002_CA_1_evaluation  13  ...              NaN             NaN
# 158549  HOBBIES_1_002_CA_1_evaluation  14  ...              NaN             NaN
# 170745  HOBBIES_1_002_CA_1_evaluation  15  ...              NaN             NaN
# 182941  HOBBIES_1_002_CA_1_evaluation  16  ...              NaN             NaN
# 195137  HOBBIES_1_002_CA_1_evaluation  17  ...              NaN             NaN
# 207333  HOBBIES_1_002_CA_1_evaluation  18  ...              NaN             NaN
# 219529  HOBBIES_1_002_CA_1_evaluation  19  ...              NaN             NaN
# 231725  HOBBIES_1_002_CA_1_evaluation  20  ...              NaN             NaN
#
# [20 rows x 9 columns]

# %%
########################### Memory usage
#################################################################################
# Let's check our memory usage
print("{:>20}: {:>8}".format('Original rolling df',sizeof_fmt(temp_df.memory_usage(index=True).sum())))

# can we minify it?
# 1. if our dataset are aligned by index 
#    you don't need 'id' 'd' 'sales' columns
temp_df = temp_df.iloc[:,3:]
print("{:>20}: {:>8}".format('Values rolling df',sizeof_fmt(temp_df.memory_usage(index=True).sum())))

# can we make it even smaller?
# carefully change dtype and/or
# use sparce matrix to minify 0s
# Also note that lgbm accepts matrixes as input
# that is good for memory reducion 
from scipy import sparse 
temp_matrix = sparse.csr_matrix(temp_df)

# restore to df
temp_matrix_restored = pd.DataFrame(temp_matrix.todense())
restored_cols = ['roll_' + str(i) for i in list(temp_matrix_restored)]
temp_matrix_restored.columns = restored_cols
# Out:
#  Original rolling df:   1.3GiB
#    Values rolling df:   1.1GiB

# %%
########################### Remove old objects
#################################################################################
del temp_df, train_df, temp_matrix, temp_matrix_restored

# %%
########################### Apply on grid_df
#################################################################################
# lets read grid from 
# https://www.kaggle.com/kyakovlev/m5-simple-fe
# to be sure that our grids are aligned by index
grid_df = pd.read_pickle(f"{OUTPUT_PATH}/grid_part_1.pkl")

# We need only 'id','d','sales'
# to make lags and rollings
grid_df = grid_df[['id','d','sales']]
SHIFT_DAY = 28

# Lags
# with 28 day shift
start_time = time.time()
print('Create lags')

LAG_DAYS = [col for col in range(SHIFT_DAY,SHIFT_DAY+15)]
grid_df = grid_df.assign(**{
        '{}_lag_{}'.format(col, l): grid_df.groupby(['id'])[col].transform(lambda x: x.shift(l))
        for l in LAG_DAYS
        for col in [TARGET]
    })

# Minify lag columns
for col in list(grid_df):
    if 'lag' in col:
        grid_df[col] = grid_df[col].astype(np.float16)

print('%0.2f min: Lags' % ((time.time() - start_time) / 60))

# Rollings
# with 28 day shift
start_time = time.time()
print('Create rolling aggs')
for i in [7,14,30,60,180]:
    print('Rolling period:', i)
    grid_df['rolling_mean_'+str(i)] = grid_df.groupby(['id'])[TARGET].apply(lambda x: x.shift(SHIFT_DAY).rolling(i).mean()).astype(np.float16)
    grid_df['rolling_std_'+str(i)]  = grid_df.groupby(['id'])[TARGET].apply(lambda x: x.shift(SHIFT_DAY).rolling(i).std()).astype(np.float16)

# Rollings
# with sliding shift
for d_shift in [1,7,14]: 
    print('Shifting period:', d_shift)
    for d_window in [7,14,30,60]:
        col_name = 'rolling_mean_tmp_'+str(d_shift)+'_'+str(d_window)
        grid_df[col_name] = grid_df.groupby(['id'])[TARGET].transform(lambda x: x.shift(d_shift).rolling(d_window).mean()).astype(np.float16)
    
print('%0.2f min: Lags' % ((time.time() - start_time) / 60))
# Out:
# Create lags
# 8.16 min: Lags
# Create rolling aggs
# Rolling period: 7
# Rolling period: 14
# Rolling period: 30
# Rolling period: 60
# Rolling period: 180
# Shifting period: 1
# Shifting period: 7
# Shifting period: 14
# 16.07 min: Lags

# %%
########################### Export
#################################################################################
print('Save lags and rollings')
FILE_NAME = 'lags_df_'+str(SHIFT_DAY)+'.pkl'
grid_df.to_pickle(f"{OUTPUT_PATH}/{FILE_NAME}")
# Out:
# Save lags and rollings

# %%
########################### Final Output
#################################################################################
pd.set_option('display.max_rows', None)
grid_df[grid_df['id']=='HOBBIES_1_002_CA_1_evaluation'].reset_index(drop=True)
# Out:
#                                  id  ...  rolling_mean_tmp_14_60
# 0     HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 1     HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 2     HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 3     HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 4     HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 5     HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 6     HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 7     HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 8     HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 9     HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 10    HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 11    HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 12    HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 13    HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 14    HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 15    HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 16    HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 17    HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 18    HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 19    HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 20    HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 21    HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 22    HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 23    HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 24    HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 25    HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 26    HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 27    HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 28    HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 29    HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 30    HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 31    HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 32    HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 33    HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 34    HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 35    HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 36    HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 37    HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 38    HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 39    HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 40    HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 41    HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 42    HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 43    HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 44    HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 45    HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 46    HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 47    HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 48    HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 49    HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 50    HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 51    HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 52    HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 53    HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 54    HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 55    HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 56    HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 57    HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 58    HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 59    HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 60    HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 61    HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 62    HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 63    HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 64    HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 65    HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 66    HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 67    HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 68    HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 69    HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 70    HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 71    HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 72    HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 73    HOBBIES_1_002_CA_1_evaluation  ...                0.233276
# 74    HOBBIES_1_002_CA_1_evaluation  ...                0.233276
# 75    HOBBIES_1_002_CA_1_evaluation  ...                0.250000
# 76    HOBBIES_1_002_CA_1_evaluation  ...                0.250000
# 77    HOBBIES_1_002_CA_1_evaluation  ...                0.233276
# 78    HOBBIES_1_002_CA_1_evaluation  ...                0.233276
# 79    HOBBIES_1_002_CA_1_evaluation  ...                0.233276
# 80    HOBBIES_1_002_CA_1_evaluation  ...                0.216675
# 81    HOBBIES_1_002_CA_1_evaluation  ...                0.233276
# 82    HOBBIES_1_002_CA_1_evaluation  ...                0.233276
# 83    HOBBIES_1_002_CA_1_evaluation  ...                0.233276
# 84    HOBBIES_1_002_CA_1_evaluation  ...                0.250000
# 85    HOBBIES_1_002_CA_1_evaluation  ...                0.250000
# 86    HOBBIES_1_002_CA_1_evaluation  ...                0.233276
# 87    HOBBIES_1_002_CA_1_evaluation  ...                0.216675
#
HOBBIES_1_002_CA_1_evaluation  ...                0.133301
# 445   HOBBIES_1_002_CA_1_evaluation  ...                0.133301
# 446   HOBBIES_1_002_CA_1_evaluation  ...                0.116638
# 447   HOBBIES_1_002_CA_1_evaluation  ...                0.133301
# 448   HOBBIES_1_002_CA_1_evaluation  ...                0.133301
# 449   HOBBIES_1_002_CA_1_evaluation  ...                0.133301
# 450   HOBBIES_1_002_CA_1_evaluation  ...                0.133301
# 451   HOBBIES_1_002_CA_1_evaluation  ...                0.133301
# 452   HOBBIES_1_002_CA_1_evaluation  ...                0.133301
# 453   HOBBIES_1_002_CA_1_evaluation  ...                0.133301
# 454   HOBBIES_1_002_CA_1_evaluation  ...                0.116638
# 455   HOBBIES_1_002_CA_1_evaluation  ...                0.166626
# 456   HOBBIES_1_002_CA_1_evaluation  ...                0.183350
# 457   HOBBIES_1_002_CA_1_evaluation  ...                0.199951
# 458   HOBBIES_1_002_CA_1_evaluation  ...                0.183350
# 459   HOBBIES_1_002_CA_1_evaluation  ...                0.183350
# 460   HOBBIES_1_002_CA_1_evaluation  ...                0.183350
# 461   HOBBIES_1_002_CA_1_evaluation  ...                0.183350
# 462   HOBBIES_1_002_CA_1_evaluation  ...                0.183350
# 463   HOBBIES_1_002_CA_1_evaluation  ...                0.183350
# 464   HOBBIES_1_002_CA_1_evaluation  ...                0.166626
# 465   HOBBIES_1_002_CA_1_evaluation  ...                0.166626
# 466   HOBBIES_1_002_CA_1_evaluation  ...                0.166626
# 467   HOBBIES_1_002_CA_1_evaluation  ...                0.166626
# 468   HOBBIES_1_002_CA_1_evaluation  ...                0.166626
# 469   HOBBIES_1_002_CA_1_evaluation  ...                0.166626
# 470   HOBBIES_1_002_CA_1_evaluation  ...                0.166626
# 471   HOBBIES_1_002_CA_1_evaluation  ...                0.166626
# 472   HOBBIES_1_002_CA_1_evaluation  ...                0.166626
# 473   HOBBIES_1_002_CA_1_evaluation  ...                0.166626
# 474   HOBBIES_1_002_CA_1_evaluation  ...                0.166626
# 475   HOBBIES_1_002_CA_1_evaluation  ...                0.183350
# 476   HOBBIES_1_002_CA_1_evaluation  ...                0.199951
# 477   HOBBIES_1_002_CA_1_evaluation  ...                0.216675
# 478   HOBBIES_1_002_CA_1_evaluation  ...                0.216675
# 479   HOBBIES_1_002_CA_1_evaluation  ...                0.216675
# 480   HOBBIES_1_002_CA_1_evaluation  ...                0.216675
# 481   HOBBIES_1_002_CA_1_evaluation  ...                0.199951
# 482   HOBBIES_1_002_CA_1_evaluation  ...                0.199951
# 483   HOBBIES_1_002_CA_1_evaluation  ...                0.199951
# 484   HOBBIES_1_002_CA_1_evaluation  ...                0.199951
# 485   HOBBIES_1_002_CA_1_evaluation  ...                0.199951
# 486   HOBBIES_1_002_CA_1_evaluation  ...                0.199951
# 487   HOBBIES_1_002_CA_1_evaluation  ...                0.216675
# 488   HOBBIES_1_002_CA_1_evaluation  ...                0.216675
# 489   HOBBIES_1_002_CA_1_evaluation  ...                0.216675
# 490   HOBBIES_1_002_CA_1_evaluation  ...                0.250000
# 491   HOBBIES_1_002_CA_1_evaluation  ...                0.250000
# 492   HOBBIES_1_002_CA_1_evaluation  ...                0.250000
# 493   HOBBIES_1_002_CA_1_evaluation  ...                0.250000
# 494   HOBBIES_1_002_CA_1_evaluation  ...                0.266602
# 495   HOBBIES_1_002_CA_1_evaluation  ...                0.250000
# 496   HOBBIES_1_002_CA_1_evaluation  ...                0.250000
# 497   HOBBIES_1_002_CA_1_evaluation  ...                0.233276
# 498   HOBBIES_1_002_CA_1_evaluation  ...                0.233276
# 499   HOBBIES_1_002_CA_1_evaluation  ...                0.233276
# 500   HOBBIES_1_002_CA_1_evaluation  ...                0.216675
# 501   HOBBIES_1_002_CA_1_evaluation  ...                0.216675
# 502   HOBBIES_1_002_CA_1_evaluation  ...                0.216675
# 503   HOBBIES_1_002_CA_1_evaluation  ...                0.250000
# 504   HOBBIES_1_002_CA_1_evaluation  ...                0.283447
# 505   HOBBIES_1_002_CA_1_evaluation  ...                0.300049
# 506   HOBBIES_1_002_CA_1_evaluation  ...                0.316650
# 507   HOBBIES_1_002_CA_1_evaluation  ...                0.300049
# 508   HOBBIES_1_002_CA_1_evaluation  ...                0.300049
# 509   HOBBIES_1_002_CA_1_evaluation  ...                0.300049
# 510   HOBBIES_1_002_CA_1_evaluation  ...                0.300049
# 511   HOBBIES_1_002_CA_1_evaluation  ...                0.300049
# 512   HOBBIES_1_002_CA_1_evaluation  ...                0.316650
# 513   HOBBIES_1_002_CA_1_evaluation  ...                0.316650
# 514   HOBBIES_1_002_CA_1_evaluation  ...                0.316650
# 515   HOBBIES_1_002_CA_1_evaluation  ...                0.266602
# 516   HOBBIES_1_002_CA_1_evaluation  ...                0.250000
# 517   HOBBIES_1_002_CA_1_evaluation  ...                0.233276
# 518   HOBBIES_1_002_CA_1_evaluation  ...                0.233276
# 519   HOBBIES_1_002_CA_1_evaluation  ...                0.233276
# 520   HOBBIES_1_002_CA_1_evaluation  ...                0.233276
# 521   HOBBIES_1_002_CA_1_evaluation  ...                0.233276
# 522   HOBBIES_1_002_CA_1_evaluation  ...                0.233276
# 523   HOBBIES_1_002_CA_1_evaluation  ...                0.233276
# 524   HOBBIES_1_002_CA_1_evaluation  ...                0.233276
# 525   HOBBIES_1_002_CA_1_evaluation  ...                0.250000
# 526   HOBBIES_1_002_CA_1_evaluation  ...                0.266602
# 527   HOBBIES_1_002_CA_1_evaluation  ...                0.266602
# 528   HOBBIES_1_002_CA_1_evaluation  ...                0.266602
# 529   HOBBIES_1_002_CA_1_evaluation  ...                0.266602
# 530   HOBBIES_1_002_CA_1_evaluation  ...                0.266602
# 531   HOBBIES_1_002_CA_1_evaluation  ...                0.283447
# 532   HOBBIES_1_002_CA_1_evaluation  ...                0.300049
# 533   HOBBIES_1_002_CA_1_evaluation  ...                0.300049
# 534   HOBBIES_1_002_CA_1_evaluation  ...                0.300049
# 535   HOBBIES_1_002_CA_1_evaluation  ...                0.283447
# 536   HOBBIES_1_002_CA_1_evaluation  ...                0.266602
# 537   HOBBIES_1_002_CA_1_evaluation  ...                0.250000
# 538   HOBBIES_1_002_CA_1_evaluation  ...                0.250000
# 539   HOBBIES_1_002_CA_1_evaluation  ...                0.250000
# 540   HOBBIES_1_002_CA_1_evaluation  ...                0.266602
# 541   HOBBIES_1_002_CA_1_evaluation  ...                0.266602
# 542   HOBBIES_1_002_CA_1_evaluation  ...                0.266602
# 543   HOBBIES_1_002_CA_1_evaluation  ...                0.283447
# 544   HOBBIES_1_002_CA_1_evaluation  ...                0.283447
# 545   HOBBIES_1_002_CA_1_evaluation  ...                0.283447
# 546   HOBBIES_1_002_CA_1_evaluation  ...                0.283447
# 547   HOBBIES_1_002_CA_1_evaluation  ...                0.266602
# 548   HOBBIES_1_002_CA_1_evaluation  ...                0.300049
# 549   HOBBIES_1_002_CA_1_evaluation  ...                0.300049
# 550   HOBBIES_1_002_CA_1_evaluation  ...                0.266602
# 551   HOBBIES_1_002_CA_1_evaluation  ...                0.266602
# 552   HOBBIES_1_002_CA_1_evaluation  ...                0.266602
# 553   HOBBIES_1_002_CA_1_evaluation  ...                0.300049
# 554   HOBBIES_1_002_CA_1_evaluation  ...                0.300049
# 555   HOBBIES_1_002_CA_1_evaluation  ...                0.316650
# 556   HOBBIES_1_002_CA_1_evaluation  ...                0.316650
# 557   HOBBIES_1_002_CA_1_evaluation  ...                0.316650
# 558   HOBBIES_1_002_CA_1_evaluation  ...                0.316650
# 559   HOBBIES_1_002_CA_1_evaluation  ...                0.350098
# 560   HOBBIES_1_002_CA_1_evaluation  ...                0.366699
# 561   HOBBIES_1_002_CA_1_evaluation  ...                0.416748
# 562   HOBBIES_1_002_CA_1_evaluation  ...                0.416748
# 563   HOBBIES_1_002_CA_1_evaluation  ...                0.433350
# 564   HOBBIES_1_002_CA_1_evaluation  ...                0.416748
# 565   HOBBIES_1_002_CA_1_evaluation  ...                0.449951
# 566   HOBBIES_1_002_CA_1_evaluation  ...                0.466553
# 567   HOBBIES_1_002_CA_1_evaluation  ...                0.483398
# 568   HOBBIES_1_002_CA_1_evaluation  ...                0.533203
# 569   HOBBIES_1_002_CA_1_evaluation  ...                0.583496
# 570   HOBBIES_1_002_CA_1_evaluation  ...                0.583496
# 571   HOBBIES_1_002_CA_1_evaluation  ...                0.583496
# 572   HOBBIES_1_002_CA_1_evaluation  ...                0.566895
# 573   HOBBIES_1_002_CA_1_evaluation  ...                0.566895
# 574   HOBBIES_1_002_CA_1_evaluation  ...                0.566895
# 575   HOBBIES_1_002_CA_1_evaluation  ...                0.566895
# 576   HOBBIES_1_002_CA_1_evaluation  ...                0.566895
# 577   HOBBIES_1_002_CA_1_evaluation  ...                0.583496
# 578   HOBBIES_1_002_CA_1_evaluation  ...                0.583496
# 579   HOBBIES_1_002_CA_1_evaluation  ...                0.583496
# 580   HOBBIES_1_002_CA_1_evaluation  ...                0.583496
# 581   HOBBIES_1_002_CA_1_evaluation  ...                0.583496
# 582   HOBBIES_1_002_CA_1_evaluation  ...                0.583496
# 583   HOBBIES_1_002_CA_1_evaluation  ...                0.583496
# 584   HOBBIES_1_002_CA_1_evaluation  ...                0.583496
# 585   HOBBIES_1_002_CA_1_evaluation  ...                0.566895
# 586   HOBBIES_1_002_CA_1_evaluation  ...                0.549805
# 587   HOBBIES_1_002_CA_1_evaluation  ...                0.549805
# 588   HOBBIES_1_002_CA_1_evaluation  ...                0.566895
# 589   HOBBIES_1_002_CA_1_evaluation  ...                0.566895
# 590   HOBBIES_1_002_CA_1_evaluation  ...                0.566895
# 591   HOBBIES_1_002_CA_1_evaluation  ...                0.549805
# 592   HOBBIES_1_002_CA_1_evaluation  ...                0.533203
# 593   HOBBIES_1_002_CA_1_evaluation  ...                0.533203
# 594   HOBBIES_1_002_CA_1_evaluation  ...                0.549805
# 595   HOBBIES_1_002_CA_1_evaluation  ...                0.566895
# 596   HOBBIES_1_002_CA_1_evaluation  ...                0.566895
# 597   HOBBIES_1_002_CA_1_evaluation  ...                0.566895
# 598   HOBBIES_1_002_CA_1_evaluation  ...                0.566895
# 599   HOBBIES_1_002_CA_1_evaluation  ...                0.566895
# 600   HOBBIES_1_002_CA_1_evaluation  ...                0.549805
# 601   HOBBIES_1_002_CA_1_evaluation  ...                0.549805
# 602   HOBBIES_1_002_CA_1_evaluation  ...                0.566895
# 603   HOBBIES_1_002_CA_1_evaluation  ...                0.549805
# 604   HOBBIES_1_002_CA_1_evaluation  ...                0.549805
# 605   HOBBIES_1_002_CA_1_evaluation  ...                0.583496
# 606   HOBBIES_1_002_CA_1_evaluation  ...                0.583496
# 607   HOBBIES_1_002_CA_1_evaluation  ...                0.600098
# 608   HOBBIES_1_002_CA_1_evaluation  ...                0.566895
# 609   HOBBIES_1_002_CA_1_evaluation  ...                0.583496
# 610   HOBBIES_1_002_CA_1_evaluation  ...                0.583496
# 611   HOBBIES_1_002_CA_1_evaluation  ...                0.600098
# 612   HOBBIES_1_002_CA_1_evaluation  ...                0.600098
# 613   HOBBIES_1_002_CA_1_evaluation  ...                0.566895
# 614   HOBBIES_1_002_CA_1_evaluation  ...                0.549805
# 615   HOBBIES_1_002_CA_1_evaluation  ...                0.533203
# 616   HOBBIES_1_002_CA_1_evaluation  ...                0.533203
# 617   HOBBIES_1_002_CA_1_evaluation  ...                0.533203
# 618   HOBBIES_1_002_CA_1_evaluation  ...                0.533203
# 619   HOBBIES_1_002_CA_1_evaluation  ...                0.500000
# 620   HOBBIES_1_002_CA_1_evaluation  ...                0.500000
# 621   HOBBIES_1_002_CA_1_evaluation  ...                0.466553
# 622   HOBBIES_1_002_CA_1_evaluation  ...                0.466553
# 623   HOBBIES_1_002_CA_1_evaluation  ...                0.416748
# 624   HOBBIES_1_002_CA_1_evaluation  ...                0.399902
# 625   HOBBIES_1_002_CA_1_evaluation  ...                0.350098
# 626   HOBBIES_1_002_CA_1_evaluation  ...                0.316650
# 627   HOBBIES_1_002_CA_1_evaluation  ...                0.300049
# 628   HOBBIES_1_002_CA_1_evaluation  ...                0.250000
# 629   HOBBIES_1_002_CA_1_evaluation  ...                0.199951
# 630   HOBBIES_1_002_CA_1_evaluation  ...                0.233276
# 631   HOBBIES_1_002_CA_1_evaluation  ...                0.233276
# 632   HOBBIES_1_002_CA_1_evaluation  ...                0.233276
# 633   HOBBIES_1_002_CA_1_evaluation  ...                0.233276
# 634   HOBBIES_1_002_CA_1_evaluation  ...                0.233276
# 635   HOBBIES_1_002_CA_1_evaluation  ...                0.233276
# 636   HOBBIES_1_002_CA_1_evaluation  ...                0.250000
# 637   HOBBIES_1_002_CA_1_evaluation  ...                0.250000
# 638   HOBBIES_1_002_CA_1_evaluation  ...                0.266602
# 639   HOBBIES_1_002_CA_1_evaluation  ...                0.283447
# 640   HOBBIES_1_002_CA_1_evaluation  ...                0.283447
# 641   HOBBIES_1_002_CA_1_evaluation  ...                0.283447
# 642   HOBBIES_1_002_CA_1_evaluation  ...                0.283447
# 643   HOBBIES_1_002_CA_1_evaluation  ...                0.283447
# 644   HOBBIES_1_002_CA_1_evaluation  ...                0.300049
# 645   HOBBIES_1_002_CA_1_evaluation  ...                0.300049
# 646   HOBBIES_1_002_CA_1_evaluation  ...                0.300049
# 647   HOBBIES_1_002_CA_1_evaluation  ...                0.300049
# 648   HOBBIES_1_002_CA_1_evaluation  ...                0.283447
# 649   HOBBIES_1_002_CA_1_evaluation  ...                0.283447
# 650   HOBBIES_1_002_CA_1_evaluation  ...                0.283447
# 651   HOBBIES_1_002_CA_1_evaluation  ...                0.283447
# 652   HOBBIES_1_002_CA_1_evaluation  ...                0.283447
# 653   HOBBIES_1_002_CA_1_evaluation  ...                0.283447
# 654   HOBBIES_1_002_CA_1_evaluation  ...                0.266602
# 655   HOBBIES_1_002_CA_1_evaluation  ...                0.250000
# 656   HOBBIES_1_002_CA_1_evaluation  ...                0.250000
# 657   HOBBIES_1_002_CA_1_evaluation  ...                0.250000
# 658   HOBBIES_1_002_CA_1_evaluation  ...                0.250000
# 659   HOBBIES_1_002_CA_1_evaluation  ...                0.250000
# 660   HOBBIES_1_002_CA_1_evaluation  ...                0.250000
# 661   HOBBIES_1_002_CA_1_evaluation  ...                0.266602
# 662   HOBBIES_1_002_CA_1_evaluation  ...                0.250000
# 663   HOBBIES_1_002_CA_1_evaluation  ...                0.266602
# 664   HOBBIES_1_002_CA_1_evaluation  ...                0.266602
# 665   HOBBIES_1_002_CA_1_evaluation  ...                0.250000
# 666   HOBBIES_1_002_CA_1_evaluation  ...                0.283447
# 667   HOBBIES_1_002_CA_1_evaluation  ...                0.266602
# 668   HOBBIES_1_002_CA_1_evaluation  ...                0.283447
# 669   HOBBIES_1_002_CA_1_evaluation  ...                0.266602
# 670   HOBBIES_1_002_CA_1_evaluation  ...                0.266602
# 671   HOBBIES_1_002_CA_1_evaluation  ...                0.250000
# 672   HOBBIES_1_002_CA_1_evaluation  ...                0.250000
# 673   HOBBIES_1_002_CA_1_evaluation  ...                0.250000
# 674   HOBBIES_1_002_CA_1_evaluation  ...                0.250000
# 675   HOBBIES_1_002_CA_1_evaluation  ...                0.250000
# 676   HOBBIES_1_002_CA_1_evaluation  ...                0.250000
# 677   HOBBIES_1_002_CA_1_evaluation  ...                0.250000
# 678   HOBBIES_1_002_CA_1_evaluation  ...                0.250000
# 679   HOBBIES_1_002_CA_1_evaluation  ...                0.250000
# 680   HOBBIES_1_002_CA_1_evaluation  ...                0.250000
# 681   HOBBIES_1_002_CA_1_evaluation  ...                0.233276
# 682   HOBBIES_1_002_CA_1_evaluation  ...                0.233276
# 683   HOBBIES_1_002_CA_1_evaluation  ...                0.233276
# 684   HOBBIES_1_002_CA_1_evaluation  ...                0.233276
# 685   HOBBIES_1_002_CA_1_evaluation  ...                0.233276
# 686   HOBBIES_1_002_CA_1_evaluation  ...                0.233276
# 687   HOBBIES_1_002_CA_1_evaluation  ...                0.233276
# 688   HOBBIES_1_002_CA_1_evaluation  ...                0.233276
# 689   HOBBIES_1_002_CA_1_evaluation  ...                0.250000
# 690   HOBBIES_1_002_CA_1_evaluation  ...                0.216675
# 691   HOBBIES_1_002_CA_1_evaluation  ...                0.233276
# 692   HOBBIES_1_002_CA_1_evaluation  ...                0.233276
# 693   HOBBIES_1_002_CA_1_evaluation  ...                0.233276
# 694   HOBBIES_1_002_CA_1_evaluation  ...                0.233276
# 695   HOBBIES_1_002_CA_1_evaluation  ...                0.233276
# 696   HOBBIES_1_002_CA_1_evaluation  ...                0.216675
# 697   HOBBIES_1_002_CA_1_evaluation  ...                0.199951
# 698   HOBBIES_1_002_CA_1_evaluation  ...                0.183350
# 699   HOBBIES_1_002_CA_1_evaluation  ...                0.166626
# 700   HOBBIES_1_002_CA_1_evaluation  ...                0.183350
# 701   HOBBIES_1_002_CA_1_evaluation  ...                0.199951
# 702   HOBBIES_1_002_CA_1_evaluation  ...                0.199951
# 703   HOBBIES_1_002_CA_1_evaluation  ...                0.199951
# 704   HOBBIES_1_002_CA_1_evaluation  ...                0.183350
# 705   HOBBIES_1_002_CA_1_evaluation  ...                0.183350
# 706   HOBBIES_1_002_CA_1_evaluation  ...                0.199951
# 707   HOBBIES_1_002_CA_1_evaluation  ...                0.216675
# 708   HOBBIES_1_002_CA_1_evaluation  ...                0.233276
# 709   HOBBIES_1_002_CA_1_evaluation  ...                0.233276
# 710   HOBBIES_1_002_CA_1_evaluation  ...                0.233276
# 711   HOBBIES_1_002_CA_1_evaluation  ...                0.266602
# 712   HOBBIES_1_002_CA_1_evaluation  ...                0.266602
# 713   HOBBIES_1_002_CA_1_evaluation  ...                0.266602
# 714   HOBBIES_1_002_CA_1_evaluation  ...                0.266602
# 715   HOBBIES_1_002_CA_1_evaluation  ...                0.266602
# 716   HOBBIES_1_002_CA_1_evaluation  ...                0.266602
# 717   HOBBIES_1_002_CA_1_evaluation  ...                0.266602
# 718   HOBBIES_1_002_CA_1_evaluation  ...                0.266602
# 719   HOBBIES_1_002_CA_1_evaluation  ...                0.266602
# 720   HOBBIES_1_002_CA_1_evaluation  ...                0.283447
# 721   HOBBIES_1_002_CA_1_evaluation  ...                0.266602
# 722   HOBBIES_1_002_CA_1_evaluation  ...                0.266602
# 723   HOBBIES_1_002_CA_1_evaluation  ...                0.250000
# 724   HOBBIES_1_002_CA_1_evaluation  ...                0.250000
# 725   HOBBIES_1_002_CA_1_evaluation  ...                0.233276
# 726   HOBBIES_1_002_CA_1_evaluation  ...                0.199951
# 727   HOBBIES_1_002_CA_1_evaluation  ...                0.199951
# 728   HOBBIES_1_002_CA_1_evaluation  ...                0.183350
# 729   HOBBIES_1_002_CA_1_evaluation  ...                0.183350
# 730   HOBBIES_1_002_CA_1_evaluation  ...                0.199951
# 731   HOBBIES_1_002_CA_1_evaluation  ...                0.216675
# 732   HOBBIES_1_002_CA_1_evaluation  ...                0.216675
# 733   HOBBIES_1_002_CA_1_evaluation  ...                0.216675
# 734   HOBBIES_1_002_CA_1_evaluation  ...                0.233276
# 735   HOBBIES_1_002_CA_1_evaluation  ...                0.233276
# 736   HOBBIES_1_002_CA_1_evaluation  ...                0.233276
# ...
# 1584  HOBBIES_1_002_CA_1_evaluation  ...                0.416748
# 1585  HOBBIES_1_002_CA_1_evaluation  ...                0.399902
# 1586  HOBBIES_1_002_CA_1_evaluation  ...                0.383301
# 1587  HOBBIES_1_002_CA_1_evaluation  ...                0.366699
# 1588  HOBBIES_1_002_CA_1_evaluation  ...                0.366699
# 1589  HOBBIES_1_002_CA_1_evaluation  ...                0.366699
# 1590  HOBBIES_1_002_CA_1_evaluation  ...                0.416748
# 1591  HOBBIES_1_002_CA_1_evaluation  ...                0.399902
# 1592  HOBBIES_1_002_CA_1_evaluation  ...                0.399902
# 1593  HOBBIES_1_002_CA_1_evaluation  ...                0.383301
# 1594  HOBBIES_1_002_CA_1_evaluation  ...                0.383301
# 1595  HOBBIES_1_002_CA_1_evaluation  ...                0.383301
# 1596  HOBBIES_1_002_CA_1_evaluation  ...                0.383301
# 1597  HOBBIES_1_002_CA_1_evaluation  ...                0.366699
# 1598  HOBBIES_1_002_CA_1_evaluation  ...                0.366699
# 1599  HOBBIES_1_002_CA_1_evaluation  ...                0.366699
# 1600  HOBBIES_1_002_CA_1_evaluation  ...                0.350098
# 1601  HOBBIES_1_002_CA_1_evaluation  ...                0.350098
# 1602  HOBBIES_1_002_CA_1_evaluation  ...                0.350098
# 1603  HOBBIES_1_002_CA_1_evaluation  ...                0.383301
# 1604  HOBBIES_1_002_CA_1_evaluation  ...                0.399902
# 1605  HOBBIES_1_002_CA_1_evaluation  ...                0.350098
# 1606  HOBBIES_1_002_CA_1_evaluation  ...                0.283447
# 1607  HOBBIES_1_002_CA_1_evaluation  ...                0.283447
# 1608  HOBBIES_1_002_CA_1_evaluation  ...                0.300049
# 1609  HOBBIES_1_002_CA_1_evaluation  ...                0.316650
# 1610  HOBBIES_1_002_CA_1_evaluation  ...                0.316650
#
OBBIES_1_002_CA_1_evaluation  ...                0.283447
# 1720  HOBBIES_1_002_CA_1_evaluation  ...                0.283447
# 1721  HOBBIES_1_002_CA_1_evaluation  ...                0.266602
# 1722  HOBBIES_1_002_CA_1_evaluation  ...                0.283447
# 1723  HOBBIES_1_002_CA_1_evaluation  ...                0.233276
# 1724  HOBBIES_1_002_CA_1_evaluation  ...                0.150024
# 1725  HOBBIES_1_002_CA_1_evaluation  ...                0.150024
# 1726  HOBBIES_1_002_CA_1_evaluation  ...                0.150024
# 1727  HOBBIES_1_002_CA_1_evaluation  ...                0.150024
# 1728  HOBBIES_1_002_CA_1_evaluation  ...                0.150024
# 1729  HOBBIES_1_002_CA_1_evaluation  ...                0.150024
# 1730  HOBBIES_1_002_CA_1_evaluation  ...                0.150024
# 1731  HOBBIES_1_002_CA_1_evaluation  ...                0.150024
# 1732  HOBBIES_1_002_CA_1_evaluation  ...                0.150024
# 1733  HOBBIES_1_002_CA_1_evaluation  ...                0.150024
# 1734  HOBBIES_1_002_CA_1_evaluation  ...                0.166626
# 1735  HOBBIES_1_002_CA_1_evaluation  ...                0.166626
# 1736  HOBBIES_1_002_CA_1_evaluation  ...                0.166626
# 1737  HOBBIES_1_002_CA_1_evaluation  ...                0.183350
# 1738  HOBBIES_1_002_CA_1_evaluation  ...                0.199951
# 1739  HOBBIES_1_002_CA_1_evaluation  ...                0.199951
# 1740  HOBBIES_1_002_CA_1_evaluation  ...                0.183350
# 1741  HOBBIES_1_002_CA_1_evaluation  ...                0.199951
# 1742  HOBBIES_1_002_CA_1_evaluation  ...                0.199951
# 1743  HOBBIES_1_002_CA_1_evaluation  ...                0.216675
# 1744  HOBBIES_1_002_CA_1_evaluation  ...                0.216675
# 1745  HOBBIES_1_002_CA_1_evaluation  ...                0.216675
# 1746  HOBBIES_1_002_CA_1_evaluation  ...                0.199951
# 1747  HOBBIES_1_002_CA_1_evaluation  ...                0.199951
# 1748  HOBBIES_1_002_CA_1_evaluation  ...                0.199951
# 1749  HOBBIES_1_002_CA_1_evaluation  ...                0.183350
# 1750  HOBBIES_1_002_CA_1_evaluation  ...                0.183350
# 1751  HOBBIES_1_002_CA_1_evaluation  ...                0.183350
# 1752  HOBBIES_1_002_CA_1_evaluation  ...                0.183350
# 1753  HOBBIES_1_002_CA_1_evaluation  ...                0.183350
# 1754  HOBBIES_1_002_CA_1_evaluation  ...                0.183350
# 1755  HOBBIES_1_002_CA_1_evaluation  ...                0.199951
# 1756  HOBBIES_1_002_CA_1_evaluation  ...                0.216675
# 1757  HOBBIES_1_002_CA_1_evaluation  ...                0.233276
# 1758  HOBBIES_1_002_CA_1_evaluation  ...                0.250000
# 1759  HOBBIES_1_002_CA_1_evaluation  ...                0.250000
# 1760  HOBBIES_1_002_CA_1_evaluation  ...                0.250000
# 1761  HOBBIES_1_002_CA_1_evaluation  ...                0.250000
# 1762  HOBBIES_1_002_CA_1_evaluation  ...                0.250000
# 1763  HOBBIES_1_002_CA_1_evaluation  ...                0.233276
# 1764  HOBBIES_1_002_CA_1_evaluation  ...                0.233276
# 1765  HOBBIES_1_002_CA_1_evaluation  ...                0.233276
# 1766  HOBBIES_1_002_CA_1_evaluation  ...                0.233276
# 1767  HOBBIES_1_002_CA_1_evaluation  ...                0.233276
# 1768  HOBBIES_1_002_CA_1_evaluation  ...                0.233276
# 1769  HOBBIES_1_002_CA_1_evaluation  ...                0.233276
# 1770  HOBBIES_1_002_CA_1_evaluation  ...                0.216675
# 1771  HOBBIES_1_002_CA_1_evaluation  ...                0.216675
# 1772  HOBBIES_1_002_CA_1_evaluation  ...                0.216675
# 1773  HOBBIES_1_002_CA_1_evaluation  ...                0.216675
# 1774  HOBBIES_1_002_CA_1_evaluation  ...                0.216675
# 1775  HOBBIES_1_002_CA_1_evaluation  ...                0.216675
# 1776  HOBBIES_1_002_CA_1_evaluation  ...                0.216675
# 1777  HOBBIES_1_002_CA_1_evaluation  ...                0.216675
# 1778  HOBBIES_1_002_CA_1_evaluation  ...                0.199951
# 1779  HOBBIES_1_002_CA_1_evaluation  ...                0.199951
# 1780  HOBBIES_1_002_CA_1_evaluation  ...                0.199951
# 1781  HOBBIES_1_002_CA_1_evaluation  ...                0.199951
# 1782  HOBBIES_1_002_CA_1_evaluation  ...                0.199951
# 1783  HOBBIES_1_002_CA_1_evaluation  ...                0.199951
# 1784  HOBBIES_1_002_CA_1_evaluation  ...                0.199951
# 1785  HOBBIES_1_002_CA_1_evaluation  ...                0.199951
# 1786  HOBBIES_1_002_CA_1_evaluation  ...                0.199951
# 1787  HOBBIES_1_002_CA_1_evaluation  ...                0.183350
# 1788  HOBBIES_1_002_CA_1_evaluation  ...                0.199951
# 1789  HOBBIES_1_002_CA_1_evaluation  ...                0.199951
# 1790  HOBBIES_1_002_CA_1_evaluation  ...                0.199951
# 1791  HOBBIES_1_002_CA_1_evaluation  ...                0.199951
# 1792  HOBBIES_1_002_CA_1_evaluation  ...                0.199951
# 1793  HOBBIES_1_002_CA_1_evaluation  ...                0.199951
# 1794  HOBBIES_1_002_CA_1_evaluation  ...                0.183350
# 1795  HOBBIES_1_002_CA_1_evaluation  ...                0.183350
# 1796  HOBBIES_1_002_CA_1_evaluation  ...                0.199951
# 1797  HOBBIES_1_002_CA_1_evaluation  ...                0.183350
# 1798  HOBBIES_1_002_CA_1_evaluation  ...                0.166626
# 1799  HOBBIES_1_002_CA_1_evaluation  ...                0.166626
# 1800  HOBBIES_1_002_CA_1_evaluation  ...                0.166626
# 1801  HOBBIES_1_002_CA_1_evaluation  ...                0.150024
# 1802  HOBBIES_1_002_CA_1_evaluation  ...                0.150024
# 1803  HOBBIES_1_002_CA_1_evaluation  ...                0.133301
# 1804  HOBBIES_1_002_CA_1_evaluation  ...                0.133301
# 1805  HOBBIES_1_002_CA_1_evaluation  ...                0.133301
# 1806  HOBBIES_1_002_CA_1_evaluation  ...                0.150024
# 1807  HOBBIES_1_002_CA_1_evaluation  ...                0.183350
# 1808  HOBBIES_1_002_CA_1_evaluation  ...                0.199951
# 1809  HOBBIES_1_002_CA_1_evaluation  ...                0.216675
# 1810  HOBBIES_1_002_CA_1_evaluation  ...                0.216675
# 1811  HOBBIES_1_002_CA_1_evaluation  ...                0.216675
# 1812  HOBBIES_1_002_CA_1_evaluation  ...                0.216675
# 1813  HOBBIES_1_002_CA_1_evaluation  ...                0.216675
# 1814  HOBBIES_1_002_CA_1_evaluation  ...                0.216675
# 1815  HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 1816  HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 1817  HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 1818  HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 1819  HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 1820  HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 1821  HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 1822  HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 1823  HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 1824  HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 1825  HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 1826  HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 1827  HOBBIES_1_002_CA_1_evaluation  ...                     NaN
# 1828  HOBBIES_1_002_CA_1_evaluation  ...                     NaN
#
# [1829 rows x 40 columns]

# %%
########################### Final list of new features
#################################################################################
grid_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47735397 entries, 0 to 47735396
# Data columns (total 40 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   id                      category
#  1   d                       int16
#  2   sales                   float64
#  3   sales_lag_28            float16
#  4   sales_lag_29            float16
#  5   sales_lag_30            float16
#  6   sales_lag_31            float16
#  7   sales_lag_32            float16
#  8   sales_lag_33            float16
#  9   sales_lag_34            float16
#  10  sales_lag_35            float16
#  11  sales_lag_36            float16
#  12  sales_lag_37            float16
#  13  sales_lag_38            float16
#  14  sales_lag_39            float16
#  15  sales_lag_40            float16
#  16  sales_lag_41            float16
#  17  sales_lag_42            float16
#  18  rolling_mean_7          float16
#  19  rolling_std_7           float16
#  20  rolling_mean_14         float16
#  21  rolling_std_14          float16
#  22  rolling_mean_30         float16
#  23  rolling_std_30          float16
#  24  rolling_mean_60         float16
#  25  rolling_std_60          float16
#  26  rolling_mean_180        float16
#  27  rolling_std_180         float16
#  28  rolling_mean_tmp_1_7    float16
#  29  rolling_mean_tmp_1_14   float16
#  30  rolling_mean_tmp_1_30   float16
#  31  rolling_mean_tmp_1_60   float16
#  32  rolling_mean_tmp_7_7    float16
#  33  rolling_mean_tmp_7_14   float16
#  34  rolling_mean_tmp_7_30   float16
#  35  rolling_mean_tmp_7_60   float16
#  36  rolling_mean_tmp_14_7   float16
#  37  rolling_mean_tmp_14_14  float16
#  38  rolling_mean_tmp_14_30  float16
#  39  rolling_mean_tmp_14_60  float16
# dtypes: category(1), float16(37), float64(1), int16(1)
# memory usage: 3.8 GB
